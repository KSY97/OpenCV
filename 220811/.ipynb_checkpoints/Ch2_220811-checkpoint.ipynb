# %%
import numpy as np
import cv2
import sys

import matplotlib.pyplot as plt

# %%
img = cv2.imread('../fig/puppy.bmp', cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# img_resize = cv2.resize(img, (1200, 50))
# cv2.imwrite('img_resize.jpg', img_resize)

if img is None:
    print('fail')
    sys.exit()

plt.figure(figsize=(30,30))
plt.subplot(131), plt.imshow(img), plt.axis('off'), plt.title('img_bgr', fontsize=20)
plt.subplot(132), plt.imshow(img_rgb), plt.axis('off'), plt.title('img_rgb', fontsize=20)
plt.subplot(133), plt.imshow(img_gray, cmap='gray'), plt.axis('off'), plt.title('img_gray', fontsize=20)
plt.show()

# cv2.namedWindow('image', cv2.WINDOW_NORMAL)
# cv2.imshow('image', img)
# cv2.imshow('image_resize', img_resize)

# while True:
#     key = cv2.waitKey()
    
#     if key == 27 or key == ord('q'):
#         break
        
# cv2.destroyAllWindows()

# %%
import os
import glob

# %%
img_list = glob.glob('../fig/my_images/*.*')
display(img_list)
# Out:
# ['../fig/my_images\\animals-2222007__340.webp',
#  '../fig/my_images\\cat-323262__340.webp',
#  '../fig/my_images\\cat-5628953__340.jpg',
#  '../fig/my_images\\cat-hide-and-seek-in-white-background-with-copyspace_71163-532.webp',
#  '../fig/my_images\\cat.bmp',
#  '../fig/my_images\\cats-4945658__340.webp',
#  '../fig/my_images\\cats-eyes-2944820__340.webp',
#  '../fig/my_images\\kittens-1916542__340.jpg',
#  '../fig/my_images\\kittens-3535404__340.jpg',
#  '../fig/my_images\\kitty-2948404__340.jpg',
#  '../fig/my_images\\puppy.bmp',
#  '../fig/my_images\\puppy2.png',
#  '../fig/my_images\\sunset-3008779__340.webp']

# %%
img_list = os.listdir('../fig/my_images/')

img_files=[]
for i in img_list:
    img_path = '../fig/my_images/' + i
    img_files.append(img_path)
    
display(img_files)


cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.setWindowProperty('image', cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

idx = 0
while True:
    
    img = cv2.imread(img_files[idx])
    
    if img is None:
        print('failed')
        break
    
    
    cv2.imshow('image', img)
    
    if cv2.waitKey(1000) == 27:
        break
        
    idx += 1
    
    if idx >= (len(img_files)):
        idx = 0

cv2.destroyAllWindows()
# Out:
# ['../fig/my_images/animals-2222007__340.webp',
#  '../fig/my_images/cat-323262__340.webp',
#  '../fig/my_images/cat-5628953__340.jpg',
#  '../fig/my_images/cat-hide-and-seek-in-white-background-with-copyspace_71163-532.webp',
#  '../fig/my_images/cat.bmp',
#  '../fig/my_images/cats-4945658__340.webp',
#  '../fig/my_images/cats-eyes-2944820__340.webp',
#  '../fig/my_images/kittens-1916542__340.jpg',
#  '../fig/my_images/kittens-3535404__340.jpg',
#  '../fig/my_images/kitty-2948404__340.jpg',
#  '../fig/my_images/puppy.bmp',
#  '../fig/my_images/puppy2.png',
#  '../fig/my_images/sunset-3008779__340.webp']

# %%
img1 = cv2.imread('../fig/cat.bmp')
img2 = cv2.imread('../fig/cat.bmp', cv2.IMREAD_GRAYSCALE)

print(type(img1))
print(img1.shape)
print(img2.shape)
print(img2.dtype)


h, w, = img1.shape[:2]

print(h, w)
# if img1 is None or img2 is None:
#     print('fail')
#     sys.exit()

# cv2.imshow('image1', img1)
# cv2.imshow('image2', img2)

# cv2.waitKey()
# cv2.destroyAllWindows()
# Out:
# <class 'numpy.ndarray'>
# (480, 640, 3)
# (480, 640)
# uint8
# 480 640
